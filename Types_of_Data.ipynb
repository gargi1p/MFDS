# %% [markdown]
# <a href="https://colab.research.google.com/github/gargi1p/MFDS/blob/main/Types_of_Data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

df=pd.DataFrame({"Sakshi": [85,82,66,92,90], "Priyanshi": [45,52,44,10,63], "Khushi": [28,3,45,44,52]})
df
# axis=0  if finding column wise
df.mean(axis=0)
# axis=1  if finding row wise
df.mean(axis=1)

url='https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv'
df=pd.read_csv(url)
df
print(df.head())
print(df.dtypes)
print(df.describe())

max_age = df['Age'].max()
print("max age:",max_age)

value_count = df['Ticket'].value_counts()
print("Value counts:",value_count)

sum_fare = df['Fare'].sum()
print("Sum of Fare:",sum_fare)

print(df.isnull().sum())  #checking for missing values

df_cleaned = df.dropna()  #drop rows with missing values

df['Age'] = df['Age'].fillna(df['Age'].median())  #Fill missing Age values with the median

print(df.isnull().sum())  #verify missing values are handled
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S
# ...
